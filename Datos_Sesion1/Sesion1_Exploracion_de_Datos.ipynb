# %% [markdown]
# # Exprésate Perú con Datos usando los datos abiertos de la Universidad Nacional de Ingeniería
# ## Datos abiertos de la Plataforma Nacional de Datos Abiertos (PNDA)
# ## Sesion 1
# ### Realizado por: Juan Luis Herencia Guerra
# ### Email: jherenciag@uni.edu.pe
# ----

# %% [markdown]
# #### Apertura de Datos

# %%
# Importar la librería
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %%
df = pd.read_csv('/content/sample_data/Listado_pacientes_nuevos_inen_enero2022_julio2024.csv', encoding='ISO-8859-1')

# %%
# Devolver el contenido de df
df
# Out:
#                                           UUID          HISTORIA  \
# 0          1  2BDE508A64EAF3D0360A1BB442B0F979  8A6591860521D333
# 1          2  2BDE508A64EAF3D0207FC7FA4FCF8231  285F27DFE78049E2
# 2          3  2BDE508A64EAF3D0337327D42A5A001E  6DDDCC115A34C888
# 3          4  2BDE508A64EAF3D06B1594A154BC1898  A63E26D3F2608940
# 4          5  2BDE508A64EAF3D0BFDEB3BD1EA23C59  9A4D51535837B6F6
# ...      ...                               ...               ...
# 43555  43556  2BDE508A64EAF3D0727983FA26F48BB4  1001794B89E925FB
# 43556  43557  2BDE508A64EAF3D02E8A3862DDDF9AF4  04344D4080202E9E
# 43557  43558  2BDE508A64EAF3D0389BC06BFBB36038  30E0FF2B0CEC7F4B
# 43558  43559  2BDE508A64EAF3D005C312F56DB25E2D  99C31219ACD4242B
# 43559  43560  2BDE508A64EAF3D0987EA597E9A86FDE  9F1915163E741157
#
#        FEC_FILIACION       SEXO  EDAD  UBIGEO_LUGAR_RESIDENCIA  \
# 0           20220103   FEMENINO    28                   150810
# ...

# %%
# Información de la estructura de la data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43560 entries, 0 to 43559
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0                            43560 non-null  int64
#  1   UUID                     43560 non-null  object
#  2   HISTORIA                 43560 non-null  object
#  3   FEC_FILIACION            43560 non-null  int64
#  4   SEXO                     43560 non-null  object
#  5   EDAD                     43560 non-null  int64
#  6   UBIGEO_LUGAR_RESIDENCIA  43560 non-null  int64
#  7   LUGAR_RESIDENCIA         43560 non-null  object
#  8   CANT_ATENCIONES_CEX      43560 non-null  int64
#  9   FECHA_CORTE              43560 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 3.3+ MB

# %%
# Saber las dimensiones del dataset
# (nro de filas, nro de columnas)
df.shape
# Out:
# (43560, 10)

# %%
# Ver la columna FEC_FILIACION
# AAAAMMDD
df['FEC_FILIACION']
# Out:
# 0        20220103
# 1        20220103
# 2        20220103
# 3        20220103
# 4        20220103
#            ...
# 43555    20240527
# 43556    20240527
# 43557    20240527
# 43558    20240527
# 43559    20240527
# Name: FEC_FILIACION, Length: 43560, dtype: int64

# %%
# Mostrar las fechas mayores al 2024-01-01
df[df['FEC_FILIACION'] > 20240101]
# Out:
#                                           UUID          HISTORIA  \
# 5554    5555  2BDE508A64EAF3D01EBD2FE07B271C07  6D859B98637AA223
# 5555    5556  2BDE508A64EAF3D04C69C5AC56725426  D0DF6256116B8F08
# 5556    5557  2BDE508A64EAF3D07968DF7D03589F55  CE9C0CEB54C88036
# 5557    5558  2BDE508A64EAF3D0354E219DFD275EE8  7B289A09EBD7DDC5
# 5558    5559  2BDE508A64EAF3D0246D53F076D11941  2B8E0DDE4BA0B375
# ...      ...                               ...               ...
# 43555  43556  2BDE508A64EAF3D0727983FA26F48BB4  1001794B89E925FB
# 43556  43557  2BDE508A64EAF3D02E8A3862DDDF9AF4  04344D4080202E9E
# 43557  43558  2BDE508A64EAF3D0389BC06BFBB36038  30E0FF2B0CEC7F4B
# 43558  43559  2BDE508A64EAF3D005C312F56DB25E2D  99C31219ACD4242B
# 43559  43560  2BDE508A64EAF3D0987EA597E9A86FDE  9F1915163E741157
#
#        FEC_FILIACION       SEXO  EDAD  UBIGEO_LUGAR_RESIDENCIA  \
# 5554        20240207   FEMENINO    57                    40307
# ...

# %%
# Mostrar los pacientes mayores a 100 años
df[df['EDAD'] > 100]
# Out:
#                                           UUID          HISTORIA  \
# 2060    2061  2BDE508A64EAF3D0C1F476D051B47E6E  02F2B105588C35C7
# 12653  12654  2BDE508A64EAF3D0FBAB9138582718C4  D954B8ED53EA4959
# 22328  22329  2BDE508A64EAF3D0589E3B176526239A  98648E5F457500C2
# 23893  23894  2BDE508A64EAF3D0B39305C8C057F3BD  1B6902DCFA3EB8C2
# 33493  33494  2BDE508A64EAF3D0E3E6E077913D1E41  996A894E01E7509B
# 39445  39446  2BDE508A64EAF3D0287E1C538FDDDBEC  608648F65A44C187
# 41664  41665  2BDE508A64EAF3D05398C019B6061399  F8666828B17820B6
# 42706  42707  2BDE508A64EAF3D0E1BA98300EA17606  C15211572B94C604
#
#        FEC_FILIACION       SEXO  EDAD  UBIGEO_LUGAR_RESIDENCIA  \
# 2060        20221220   FEMENINO   101                   211305
# 12653       20220503  MASCULINO   102                   150115
# 22328       20230525   FEMENINO   101                   150115
# 23893       20230506  MASCULINO   102                   150117
# ...

# %%
# ¿Cuantos son?
df[df['EDAD'] > 100].shape[0] # cantidad de registros
# Out:
# 8

# %%
# Hay niños [1, 12] ?
df[(df['EDAD'] >= 1) & (df['EDAD'] <= 12)] # quien_mostrar[condiciones]
# Out:
#                                           UUID          HISTORIA  \
# 46        47  2BDE508A64EAF3D0C3B0E339732608F4  22C7AC48B1A1AAB2
# 47        48  2BDE508A64EAF3D0FB4368B31FDB88CB  C3CADD853A9985B9
# 60        61  2BDE508A64EAF3D07C89C16CE2993812  6D94005CE03A34D0
# 75        76  2BDE508A64EAF3D07A65B858B5C3A28A  1269B79B5E468422
# 120      121  2BDE508A64EAF3D022F6E7DEA2F1E3E2  E2A9EC19ACCB0FD0
# ...      ...                               ...               ...
# 43398  43399  2BDE508A64EAF3D007F0451FF098EF99  C02A8E2060FE38D0
# 43426  43427  2BDE508A64EAF3D0E328AFDA35006B05  B1043943F150FE7D
# 43484  43485  2BDE508A64EAF3D06F92C06CADFA0128  6C72134F52B20E5A
# 43537  43538  2BDE508A64EAF3D0425D59D0302B4871  B284CC9C07FCECA5
# 43551  43552  2BDE508A64EAF3D0C7924B94C6DC75F1  FA70B05602E00FEE
#
#        FEC_FILIACION       SEXO  EDAD  UBIGEO_LUGAR_RESIDENCIA  \
# 46          20220112  MASCULINO    12                    90204
# ...

# %%
df['LUGAR_RESIDENCIA']
# Out:
# 0                  LIMA-HUAURA-SANTA MARIA
# 1                  LIMA-LIMA-INDEPENDENCIA
# 2                  LIMA-HUAURA-SANTA MARIA
# 3            CAJAMARCA-CAJAMARCA-CAJAMARCA
# 4                          LIMA-LIMA-BRENA
#                        ...
# 43555                LIMA-LIMA-CIENEGUILLA
# 43556             ICA-CHINCHA-PUEBLO NUEVO
# 43557          LIMA-LIMA-SANTIAGO DE SURCO
# 43558     LIMA-LIMA-SAN JUAN DE LURIGANCHO
# 43559      LORETO-ALTO AMAZONAS-YURIMAGUAS
# Name: LUGAR_RESIDENCIA, Length: 43560, dtype: object
